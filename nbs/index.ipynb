# %% [markdown]
# # ML Deploy Reference

# %% [markdown]
# This is the **navigation homepage** for the notebook-first ML deployment reference.
#
# Read notebooks in the structure below to understand the system from architecture to execution details.

# %% [markdown]
# ## Foundations
#
# - [Platform narrative](platform_narrative.html)
# - [Core module baseline](core.html)

# %% [markdown]
# ## Lifecycle notebooks
#
# - [Data loading and exploration](data.html)
# - [Model training](model_training.html)
# - [Vertical slice reference](vertical_slice.html)
# - [Web UI contracts](webui_contracts.html)

# %% [markdown]
# ## Architecture analysis notebooks
#
# - [System interaction analysis](system_interaction_analysis.html)

# %% [markdown]
# ## Topology and operations notebooks
#
# - [MLflow parity](mlflow_parity.html)
# - [Execution backends](execution_backends.html)
# - [Notebook intake validation](notebook_intake.html)
# - [Terraform bootstrap](terraform_bootstrap.html)
#
# ## Deprecated notebook
#
# - [Infrastructure overview (deprecated, merged into platform narrative)](infrastructure_overview.html)
